# %% [markdown]
# This notebook will walk through the process needed to import CSV and excel files, filter data frames by row and column and plots the filtered data.

# %%
import Pkg; 
using Pkg; 
Pkg.add(["CSV", "DataFrames", "XLSX", "Statistics", "Plots"])
# Out:
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.8/Project.toml`
#   No Changes to `~/.julia/environments/v1.8/Manifest.toml`

# %%
using CSV, DataFrames, XLSX, Statistics, Plots

# %% [markdown]
# Define file path for data file

# %%
file_path = "/Users/KatieLukow/Documents/git-repos/fitted_ECM/PIECM/data/HPPC/230320_MBPF_Investigation_25kpa_11_0043_Channel_6_Wb_1.csv"
# Out:
# "/Users/KatieLukow/Documents/git-repos/fitted_ECM/PIECM/data/HPPC/230320_MBPF_Investigation_25kpa_11_0043_Channel_6_Wb_1.csv"

# %% [markdown]
# The following functions will import the data from the Arbin export to a DataFrame to allow ease of manipulation. Ensure the correct import is used based on file type. If .xslx file, a sheet name is required.

# %%
sheet_name = "n/a"
# Out:
# "n/a"

# %%
data_import_csv(file) = CSV.read(file, DataFrame)
data_import_excel(file, sheet) = DataFrame(XLSX.readtable(file, sheet))
# Out:
# data_import_excel (generic function with 1 method)

# %%
data = data_import_csv(file_path)
# Out:
# 22968×39 DataFrame
#    Row │ Data_Point  Date_Time         Test_Time(s)  Step_Time(s)  Cycle_Index ⋯
#        │ Int64       String31          Float64       Float64       Int64       ⋯
# ───────┼────────────────────────────────────────────────────────────────────────
#      1 │          1  20/03/2023 16:09        1.0           1.0               1 ⋯
#      2 │          2  20/03/2023 16:09        2.0           2.0               1
#      3 │          3  20/03/2023 16:09        3.0002        3.0002            1
#      4 │          4  20/03/2023 16:09        4.0001        4.0001            1
#      5 │          5  20/03/2023 16:09        5.0001        5.0001            1 ⋯
#      6 │          6  20/03/2023 16:09        6.0001        6.0001            1
#      7 │          7  20/03/2023 16:10        7.0001        7.0001            1
#      8 │          8  20/03/2023 16:10        8.0002        8.0002            1
#      9 │          9  20/03/2023 16:10        9.0002        9.0002            1 ⋯
#     10 │         10  20/03/2023 16:10       10.0001       10.0001            1
#     11 │         11  20/03/2023 16:10       11.0001       11.0001            1
#    ⋮   │     ⋮              ⋮               ⋮             ⋮             ⋮      ⋱
#  22959 │      22959  21/03/2023 15:18    82880.7         430.001             5
#  22960 │      22960  21/03/2023 15:18    82890.7         440.0               5 ⋯
#  22961 │      22961  21/03/2023 15:18    82900.7         450.0               5
#  22962 │      22962  21/03/2023 15:18    82910.7         460.0               5
#  22963 │      22963  21/03/2023 15:18    82920.7         470.0               5
#  22964 │      22964  21/03/2023 15:19    82930.7         480.001             5 ⋯
#  22965 │      22965  21/03/2023 15:19    82940.7         490.0               5
#  22966 │      22966  21/03/2023 15:19    82950.7         500.0               5
#  22967 │      22967  21/03/2023 15:19    82953.7         503.014             5
#  22968 │      22968  21/03/2023 15:19    82961.4           7.6908            5 ⋯
#                                                34 columns and 22947 rows omitted

# %% [markdown]
# The names from the DataFrame can then be listed and filtered to only maintain required data.

# %%
show(names(data))
# Out:
# ["Data_Point", "Date_Time", "Test_Time(s)", "Step_Time(s)", "Cycle_Index", "Step_Index", "TC_Counter1", "TC_Counter2", "TC_Counter3", "TC_Counter4", "Current(A)", "Voltage(V)", "Power(W)", "Charge_Capacity(Ah)", "Discharge_Capacity(Ah)", "Charge_Energy(Wh)", "Discharge_Energy(Wh)", "ACR(Ohm)", "dV/dt(V/s)", "Internal_Resistance(Ohm)", "dQ/dV(Ah/V)", "dV/dQ(V/Ah)", "MetaCode_MV_UD1", "MetaCode_MV_UD2", "MetaCode_MV_UD3", "MetaCode_MV_UD4", "MetaCode_MV_UD5", "MetaCode_MV_UD6", "MetaCode_MV_UD7", "MetaCode_MV_UD8", "MetaCode_MV_UD9", "MetaCode_MV_UD10", "MetaCode_MV_UD11", "Aux_Temperature_1(C)", "Aux_dT/dt_1(C)", "Aux_Temperature_2(C)", "Aux_dT/dt_2(C)", "Aux_Temperature_3(C)", "Aux_dT/dt_3(C)"]

# %%
data_fil = select(data, "Date_Time", "Test_Time(s)", "Step_Index","TC_Counter1", "TC_Counter2", "Voltage(V)", "Current(A)")
# Out:
# 22968×7 DataFrame
#    Row │ Date_Time         Test_Time(s)  Step_Index  TC_Counter1  TC_Counter2  ⋯
#        │ String31          Float64       Int64       Int64        Int64        ⋯
# ───────┼────────────────────────────────────────────────────────────────────────
#      1 │ 20/03/2023 16:09        1.0              1            0            0  ⋯
#      2 │ 20/03/2023 16:09        2.0              1            0            0
#      3 │ 20/03/2023 16:09        3.0002           1            0            0
#      4 │ 20/03/2023 16:09        4.0001           1            0            0
#      5 │ 20/03/2023 16:09        5.0001           1            0            0  ⋯
#      6 │ 20/03/2023 16:09        6.0001           1            0            0
#      7 │ 20/03/2023 16:10        7.0001           1            0            0
#      8 │ 20/03/2023 16:10        8.0002           1            0            0
#      9 │ 20/03/2023 16:10        9.0002           1            0            0  ⋯
#     10 │ 20/03/2023 16:10       10.0001           1            0            0
#     11 │ 20/03/2023 16:10       11.0001           1            0            0
#    ⋮   │        ⋮               ⋮            ⋮            ⋮            ⋮       ⋱
#  22959 │ 21/03/2023 15:18    82880.7             49            0            4
#  22960 │ 21/03/2023 15:18    82890.7             49            0            4  ⋯
#  22961 │ 21/03/2023 15:18    82900.7             49            0            4
#  22962 │ 21/03/2023 15:18    82910.7             49            0            4
#  22963 │ 21/03/2023 15:18    82920.7             49            0            4
#  22964 │ 21/03/2023 15:19    82930.7             49            0            4  ⋯
#  22965 │ 21/03/2023 15:19    82940.7             49            0            4
#  22966 │ 21/03/2023 15:19    82950.7             49            0            4
#  22967 │ 21/03/2023 15:19    82953.7             49            0            4
#  22968 │ 21/03/2023 15:19    82961.4             50            0            4  ⋯
#                                                 2 columns and 22947 rows omitted

# %% [markdown]
# Data can then be filtered to only contain specific step indexes. The following is an example to filter out the HPPC pulse profile.

# %%
steps = [16,17,18,19]
# Out:
# 4-element Vector{Int64}:
#  16
#  17
#  18
#  19

# %%
hppc_all = filter(row -> row."Step_Index" == steps[1] || row."Step_Index" == steps[2] || row."Step_Index" == steps[3] || row."Step_Index" == steps[4], data_fil)
# Out:
# 6698×7 DataFrame
#   Row │ Date_Time         Test_Time(s)  Step_Index  TC_Counter1  TC_Counter2   ⋯
#       │ String31          Float64       Int64       Int64        Int64         ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#     1 │ 20/03/2023 23:13       25437.5          16            0            0   ⋯
#     2 │ 20/03/2023 23:14       25497.5          16            0            0
#     3 │ 20/03/2023 23:15       25557.5          16            0            0
#     4 │ 20/03/2023 23:16       25617.5          16            0            0
#     5 │ 20/03/2023 23:17       25677.5          16            0            0   ⋯
#     6 │ 20/03/2023 23:17       25677.5          16            0            0
#     7 │ 20/03/2023 23:17       25677.6          17            0            0
#     8 │ 20/03/2023 23:17       25677.7          17            0            0
#     9 │ 20/03/2023 23:17       25677.8          17            0            0   ⋯
#    10 │ 20/03/2023 23:17       25677.9          17            0            0
#    11 │ 20/03/2023 23:17       25678.0          17            0            0
#   ⋮   │        ⋮               ⋮            ⋮            ⋮            ⋮        ⋱
#  6689 │ 21/03/2023 07:28       55125.4          19           10            0
#  6690 │ 21/03/2023 07:28       55125.5          19           10            0   ⋯
#  6691 │ 21/03/2023 07:28       55125.6          19           10            0
#  6692 │ 21/03/2023 07:28       55125.7          19           10            0
#  6693 │ 21/03/2023 07:28       55125.8          19           10            0
#  6694 │ 21/03/2023 07:28       55125.9          19           10            0   ⋯
#  6695 │ 21/03/2023 07:28       55126.0          19           10            0
#  6696 │ 21/03/2023 07:28       55126.1          19           10            0
#  6697 │ 21/03/2023 07:28       55126.2          19           10            0
#  6698 │ 21/03/2023 07:28       55126.2          19           10            0   ⋯
#                                                  2 columns and 6677 rows omitted

# %% [markdown]
# Finally, the data can be filtered to aa specific SOC. Please note that step indexes and the following filter are schedule based, and as such should be adjusted for the specific test protocol that was run.

# %%
soc = 0.8
soc_increments = 10
# Out:
# 10

# %%
tc1 = (100 - (soc * 100)) / soc_increments # convert soc to TC_Counter1 value
# Out:
# 2.0

# %%
hppc_80 = filter(row -> row."TC_Counter1" == tc1, hppc_all)
# Out:
# 609×7 DataFrame
#  Row │ Date_Time         Test_Time(s)  Step_Index  TC_Counter1  TC_Counter2  V ⋯
#      │ String31          Float64       Int64       Int64        Int64        F ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 21/03/2023 00:51       31297.0          16            2            0    ⋯
#    2 │ 21/03/2023 00:52       31357.0          16            2            0
#    3 │ 21/03/2023 00:53       31417.0          16            2            0
#    4 │ 21/03/2023 00:54       31477.0          16            2            0
#    5 │ 21/03/2023 00:55       31537.0          16            2            0    ⋯
#    6 │ 21/03/2023 00:55       31537.0          16            2            0
#    7 │ 21/03/2023 00:55       31537.1          17            2            0
#    8 │ 21/03/2023 00:55       31537.2          17            2            0
#    9 │ 21/03/2023 00:55       31537.3          17            2            0    ⋯
#   10 │ 21/03/2023 00:55       31537.4          17            2            0
#   11 │ 21/03/2023 00:55       31537.5          17            2            0
#   ⋮  │        ⋮               ⋮            ⋮            ⋮            ⋮         ⋱
#  600 │ 21/03/2023 00:56       31596.3          19            2            0
#  601 │ 21/03/2023 00:56       31596.4          19            2            0    ⋯
#  602 │ 21/03/2023 00:56       31596.5          19            2            0
#  603 │ 21/03/2023 00:56       31596.6          19            2            0
#  604 │ 21/03/2023 00:56       31596.7          19            2            0
#  605 │ 21/03/2023 00:56       31596.8          19            2            0    ⋯
#  606 │ 21/03/2023 00:56       31596.9          19            2            0
#  607 │ 21/03/2023 00:56       31597.0          19            2            0
#  608 │ 21/03/2023 00:56       31597.1          19            2            0
#  609 │ 21/03/2023 00:56       31597.1          19            2            0    ⋯
#                                                   2 columns and 588 rows omitted

# %% [markdown]
# Finally, we can plot the data.

# %%
plt = plot(hppc_80[:, "Test_Time(s)"], hppc_80[:,"Voltage(V)"], xlabel = "Test Time [s]", ylabel = "Voltage [V]", label = "80% SOC")
